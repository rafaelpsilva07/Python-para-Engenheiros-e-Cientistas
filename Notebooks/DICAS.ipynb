# %% [markdown]
# # DICA 2 - Automatização - estudo guiado

# %% [markdown]
# ## Usando as funções nativas do Python (1 a 6)

# %%
# Seção 1

Path = 'C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_'
Test_numbers = list(range(1,6))

# %%
#Seção 3

for i in Test_numbers:
    file_name = Path + str(i) + ".txt"
    print(file_name)
# Out:
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_1.txt
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_2.txt
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_3.txt
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_4.txt
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_5.txt

# %%
# Seção 6

with open(file_name) as f:
    linhas = f.readlines()
    f.close
    
#Seção 4 métodos pra listas
linhas.index('TESTE\n')

#Seção 2 listas
linhas[6:]
# Out:
# ['ID,A,B\n',
#  '201,40401,0.00497512437810945\n',
#  '202,40804,0.00495049504950495\n',
#  '203,41209,0.00492610837438424\n',
#  '204,41616,0.00490196078431373\n',
#  '205,42025,0.0048780487804878\n',
#  '206,42436,0.00485436893203883\n',
#  '207,42849,0.00483091787439614\n',
#  '208,43264,0.00480769230769231\n',
#  '209,43681,0.00478468899521531\n',
#  '210,44100,0.00476190476190476\n',
#  '211,44521,0.004739336492891\n',
#  '212,44944,0.00471698113207547\n',
#  '213,45369,0.00469483568075117\n',
#  '214,45796,0.00467289719626168\n',
#  '215,46225,0.00465116279069767\n',
#  '216,46656,0.00462962962962963\n',
#  '217,47089,0.00460829493087558\n',
#  '218,47524,0.00458715596330275\n',
#  '219,47961,0.0045662100456621\n',
#  '220,48400,0.00454545454545455\n',
#  '221,48841,0.00452488687782805\n',
#  '222,49284,0.0045045045045045\n',
#  '223,49729,0.00448430493273543\n',
#  '224,50176,0.00446428571428571\n',
#  '225,50625,0.00444444444444444\n',
#  '226,51076,0.00442477876106195\n',
# ...

# %%
arquivo_full = ['ID,A,B\n']

for i in Test_numbers:
    file_name = Path + str(i) + ".txt"


    with open(file_name) as f:
        linhas = f.readlines()
        f.close
    n_linha = linhas.index('TESTE\n')

    arquivo_full.extend(linhas[7:])

# %%
arquivo_full
# Out:
# ['ID,A,B\n',
#  '1,1,1\n',
#  '2,4,0.5\n',
#  '3,9,0.333333333333333\n',
#  '4,16,0.25\n',
#  '5,25,0.2\n',
#  '6,36,0.166666666666667\n',
#  '7,49,0.142857142857143\n',
#  '8,64,0.125\n',
#  '9,81,0.111111111111111\n',
#  '10,100,0.1\n',
#  '11,121,0.0909090909090909\n',
#  '12,144,0.0833333333333333\n',
#  '13,169,0.0769230769230769\n',
#  '14,196,0.0714285714285714\n',
#  '15,225,0.0666666666666667\n',
#  '16,256,0.0625\n',
#  '17,289,0.0588235294117647\n',
#  '18,324,0.0555555555555556\n',
#  '19,361,0.0526315789473684\n',
#  '20,400,0.05\n',
#  '21,441,0.0476190476190476\n',
#  '22,484,0.0454545454545455\n',
#  '23,529,0.0434782608695652\n',
#  '24,576,0.0416666666666667\n',
#  '25,625,0.04\n',
#  '26,676,0.0384615384615385\n',
#  '27,729,0.037037037037037\n',
#  '28,784,0.0357142857142857\n',
#  '29,841,0.0344827586206897\n',
#  '30,900,0.0333333333333333\n',
#  '31,961,0.032258064516129\n',
#  '32,1024,0.03125\n',
#  '33,1089,0.0303030303030303\n',
# ...

# %%
text = 'Testes \n'
for i in enumerate(arquivo_full):
    text += arquivo_full[i[0]]
text
# Out:
# 'Testes \nID,A,B\n1,1,1\n2,4,0.5\n3,9,0.333333333333333\n4,16,0.25\n5,25,0.2\n6,36,0.166666666666667\n7,49,0.142857142857143\n8,64,0.125\n9,81,0.111111111111111\n10,100,0.1\n11,121,0.0909090909090909\n12,144,0.0833333333333333\n13,169,0.0769230769230769\n14,196,0.0714285714285714\n15,225,0.0666666666666667\n16,256,0.0625\n17,289,0.0588235294117647\n18,324,0.0555555555555556\n19,361,0.0526315789473684\n20,400,0.05\n21,441,0.0476190476190476\n22,484,0.0454545454545455\n23,529,0.0434782608695652\n24,576,0.0416666666666667\n25,625,0.04\n26,676,0.0384615384615385\n27,729,0.037037037037037\n28,784,0.0357142857142857\n29,841,0.0344827586206897\n30,900,0.0333333333333333\n31,961,0.032258064516129\n32,1024,0.03125\n33,1089,0.0303030303030303\n34,1156,0.0294117647058824\n35,1225,0.0285714285714286\n36,1296,0.0277777777777778\n37,1369,0.027027027027027\n38,1444,0.0263157894736842\n39,1521,0.0256410256410256\n40,1600,0.025\n41,1681,0.024390243902439\n42,1764,0.0238095238095238\n43,1849,0.0232558
# ...

# %%
# Seção 6
new_file = 'C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/concat_testes.txt'

with open(new_file, 'w') as f:
    f.write(text)
    f.close

# %% [markdown]
# ## Usando Pandas (9)

# %%
for i in Test_numbers:
    file_name = Path + str(i) + ".txt"
    print(file_name)
# Out:
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_1.txt
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_2.txt
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_3.txt
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_4.txt
# C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/teste_5.txt

# %%
import pandas as pd


DF_list = []

for i in Test_numbers:
    file_name = Path + str(i) + ".txt"
    DF_list.append(pd.read_csv(file_name,skiprows=6))

# %%
#9.5

Concat_DF = pd.concat(DF_list)
Concat_DF
# Out:
#      ID      A         B
# 0     1      1  1.000000
# 1     2      4  0.500000
# 2     3      9  0.333333
# 3     4     16  0.250000
# 4     5     25  0.200000
# ..  ...    ...       ...
# 45  246  60516  0.004065
# 46  247  61009  0.004049
# 47  248  61504  0.004032
# 48  249  62001  0.004016
# 49  250  62500  0.004000
#
# [250 rows x 3 columns]

# %%
Concat_DF.to_excel('C:/Users/Pichau/Desktop/Dicas_automatização/Arquivos_teste/CONCAT_PANDAS.xlsx')
